# %% [markdown]
# # AIRLINE PASSENGER SATISFACTION: DATA PREPROCESSING AND EDA

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv(r'train.csv')
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %% [markdown]
# ## Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33805 entries, 0 to 33804
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         33805 non-null  int64
#  1   id                                 33805 non-null  int64
#  2   Gender                             33805 non-null  object
#  3   Customer Type                      33805 non-null  object
#  4   Age                                33805 non-null  int64
#  5   Type of Travel                     33805 non-null  object
#  6   Class                              33805 non-null  object
#  7   Flight Distance                    33805 non-null  int64
#  8   Inflight wifi service              33805 non-null  int64
#  9   Departure/Arrival time convenient  33805 non-null  int64
#  10  Ease of Online booking             33805 non-null  int64
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0                           33805
# id                                   33805
# Gender                                   2
# Customer Type                            2
# Age                                     75
# Type of Travel                           2
# Class                                    3
# Flight Distance                       3478
# Inflight wifi service                    6
# Departure/Arrival time convenient        6
# Ease of Online booking                   6
# Gate location                            5
# Food and drink                           6
# Online boarding                          6
# Seat comfort                             6
# Inflight entertainment                   6
# On-board service                         6
# Leg room service                         6
# Baggage handling                         5
# Checkin service                          6
# Inflight service                         6
# Cleanliness                              6
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0             id           Age  Flight Distance  \
# count  33805.000000   33805.000000  33805.000000     33805.000000
# mean   16919.997338   64860.731756     39.235291      1187.381926
# std     9758.811875   37422.009469     15.116739       996.266777
# min        0.000000       8.000000      7.000000        31.000000
# 25%     8469.000000   32513.000000     27.000000       409.000000
# 50%    16920.000000   64700.000000     40.000000       838.000000
# 75%    25371.000000   97327.000000     51.000000      1743.000000
# max    33822.000000  129878.000000     85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count           33805.000000                       33805.000000
# mean                2.731016                           3.055613
# std                 1.331325                           1.530673
# min                 0.000000                           0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                            0
# id                                    0
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# ...

# %%
print(df['Age'].value_counts())
# Out:
# Age
# 25    943
# 39    932
# 40    870
# 44    797
# 41    783
#      ...
# 79     15
# 74     15
# 76     15
# 78      7
# 85      5
# Name: count, Length: 75, dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
numerical_cols = ['Age', 'Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33805 entries, 0 to 33804
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         33805 non-null  int64
#  1   id                                 33805 non-null  int64
#  2   Gender                             33805 non-null  object
#  3   Customer Type                      33805 non-null  object
#  4   Age                                33805 non-null  int64
#  5   Type of Travel                     33805 non-null  object
#  6   Class                              33805 non-null  object
#  7   Flight Distance                    33805 non-null  int64
#  8   Inflight wifi service              33805 non-null  int64
#  9   Departure/Arrival time convenient  33805 non-null  int64
#  10  Ease of Online booking             33805 non-null  int64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0             id           Age  Flight Distance  \
# count  33805.000000   33805.000000  33805.000000     33805.000000
# mean   16919.997338   64860.731756     39.235291      1187.381926
# std     9758.811875   37422.009469     15.116739       996.266777
# min        0.000000       8.000000      7.000000        31.000000
# 25%     8469.000000   32513.000000     27.000000       409.000000
# 50%    16920.000000   64700.000000     40.000000       838.000000
# 75%    25371.000000   97327.000000     51.000000      1743.000000
# max    33822.000000  129878.000000     85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count           33805.000000                       33805.000000
# mean                2.731016                           3.055613
# std                 1.331325                           1.530673
# min                 0.000000                           0.000000
# ...

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# # Hist Plot

# %%
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[col], bins=30, kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()
# Out:
# C:\Users\BHARATH BATHINI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\BHARATH BATHINI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\BHARATH BATHINI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# from plot1: The passengers between the age 30-50 are in maximum number.

# %% [markdown]
# from plot2: The most number of flithgs travelling in 1000 km range

# %% [markdown]
# from plot3: The most of the flights are departuring without any delay

# %% [markdown]
# from plot4: The flights upto 3000 are very less in arrrival delay in minutes

# %% [markdown]
# # Box Plot

# %%
# Box plots for numerical data
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=df, y=col)
    plt.title(f'Box Plot of {col}')
    plt.show()

# %% [markdown]
# from plot1: The passengers between the age 30-50 are in maximum number.

# %% [markdown]
# from plot2: The maximum number of flights are travlling 1000-2000 km distance and some of the flights are travelling  4000 and 5000 km distance

# %% [markdown]
# frpm plot3: The

# %% [markdown]
# # Count Plot

# %%
# Categorical Features
categorical_features = ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'Inflight wifi service', 
                         'Departure/Arrival time convenient', 'Ease of Online booking', 'Gate location', 
                         'Food and drink', 'Online boarding', 'Seat comfort', 'Inflight entertainment', 
                         'On-board service', 'Leg room service', 'Baggage handling', 'Checkin service', 
                         'Inflight service', 'Cleanliness']
for feature in categorical_features:
    sns.countplot(x=feature, data=df)
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# # Scatter Plot

# %%
from plot1: The females passengers are a little high in travelling than male passengers
from plot2: The most number of customers are loyal to the airlines,very less customers are disloayal
from plot3: The bussiness travellers are high than the personal travellers
from plot4: The most number of travellers are traveling in bussiness class , second highest customers are travelling in eco and very less customers are travwlling in ecoplus
from plot5: The

# %%
# 17. Departure Delay vs. Satisfaction
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Departure Delay in Minutes', y='satisfaction', data=df)
plt.title('Departure Delay vs. Satisfaction')
plt.xlabel('Departure Delay (Minutes)')
plt.ylabel('Satisfaction')
plt.show()

# 18. Arrival Delay vs. Satisfaction
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Arrival Delay in Minutes', y='satisfaction', data=df)
plt.title('Arrival Delay vs. Satisfaction')
plt.xlabel('Arrival Delay (Minutes)')
plt.ylabel('Satisfaction')
plt.show()

# %% [markdown]
# # Heatmap

# %%
# 19. Correlation Heatmap of All Numerical Features
plt.figure(figsize=(12, 10))
correlation_matrix = df[['Age', 'Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# # catplot

# %%
# 20. Satisfaction by Class and Type of Travel
plt.figure(figsize=(12, 8))
sns.catplot(x='Class', hue='Type of Travel', col='satisfaction', data=df, kind='count', height=6, aspect=1.5)
plt.title('Satisfaction by Class and Type of Travel')
plt.show()

# %%
from plot1: The personal travelers are  neutral satisfied fron the eco class are maximum , from the business class the business travellers are maximum dissatisfied and from the eco plus class the very personal and business travellers
from plot2: The business calss travellers are most satisfied in the business class.
